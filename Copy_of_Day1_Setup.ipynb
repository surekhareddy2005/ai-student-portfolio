# %% [markdown]
# <a href="https://colab.research.google.com/github/surekhareddy2005/ai-student-portfolio/blob/main/Copy_of_Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skills needed for successful AI implementation, from foundational technical abilities to high-level strategic thinking:
#
# *   **Foundation (Layers 1 & 2):** Starts with basic **Data & Infrastructure** (data engineering, cloud computing) and **Machine Learning Algorithms & Models** (building, training, deploying ML/DL models).
# *   **Domain Expertise (Layer 3):** Builds upon technical skills by integrating specific **Industry or Problem Domain Knowledge** to apply AI effectively to real-world challenges.
# *   **Ethics & Governance (Layer 4):** Emphasizes the critical importance of **Responsible AI Practices**, including fairness, privacy, transparency, and regulatory compliance.
# *   **Strategic Vision (Layer 5):** Culminates in **Strategic Vision & Application**, focusing on how AI creates business value, drives innovation, and aligns with organizational goals.
